# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Here we are importing the raw data from repository. Next step is to see the first head data

# %%
telco_customers = pd.read_csv('data/Dataset_ATS_v2.csv')

telco_customers.head()
# Out:
#    gender  SeniorCitizen Dependents  tenure PhoneService MultipleLines  \
# 0  Female              0         No       1           No            No
# 1    Male              0         No      41          Yes            No
# 2  Female              0        Yes      52          Yes            No
# 3  Female              0         No       1          Yes            No
# 4    Male              0         No      67          Yes            No
#
#   InternetService        Contract  MonthlyCharges Churn
# 0             DSL  Month-to-month              25   Yes
# 1             DSL        One year              25    No
# 2             DSL  Month-to-month              19    No
# 3             DSL        One year              76   Yes
# 4     Fiber optic  Month-to-month              51    No

# %% [markdown]
# Based on the table

# %%
telco_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   gender           7043 non-null   object
#  1   SeniorCitizen    7043 non-null   int64
#  2   Dependents       7043 non-null   object
#  3   tenure           7043 non-null   int64
#  4   PhoneService     7043 non-null   object
#  5   MultipleLines    7043 non-null   object
#  6   InternetService  7043 non-null   object
#  7   Contract         7043 non-null   object
#  8   MonthlyCharges   7043 non-null   int64
#  9   Churn            7043 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 550.4+ KB

# %%
telco_customers.shape
# Out:
# (7043, 10)

# %% [markdown]
# The raw dataset contains: 7043 Columns and 10 Rows.
# Next steps we'll check whether there are missing values

# %%
telco_customers.isnull().any()
# Out:
# gender             False
# SeniorCitizen      False
# Dependents         False
# tenure             False
# PhoneService       False
# MultipleLines      False
# InternetService    False
# Contract           False
# MonthlyCharges     False
# Churn              False
# dtype: bool

# %% [markdown]
# Seems like there are no missing value so this is a perfectly clean data. Let's take a look at brief overview of the statistical data

# %%
telco_customers.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.758768
# std         0.368612    24.559481       30.091650
# min         0.000000     0.000000       18.000000
# 25%         0.000000     9.000000       36.000000
# 50%         0.000000    29.000000       70.000000
# 75%         0.000000    55.000000       90.000000
# max         1.000000    72.000000      119.000000

# %% [markdown]
# Here we only see ``SeniorCitizen``, ``tenure``, and ``MonthlyCharges`` out of 10 variable appears on the table because out of all column only 3 contains numerical values
